# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-bab268ba-3886-40c8-b80f-1cbdee94ef91" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bab268ba-3886-40c8-b80f-1cbdee94ef91">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.csv to test.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("test.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 0           0  19556  Female     Loyal Customer   52  Business travel
# 1           1  90035  Female     Loyal Customer   36  Business travel
# 2           2  12360    Male  disloyal Customer   20  Business travel
# 3           3  77959    Male     Loyal Customer   44  Business travel
# 4           4  36875  Female     Loyal Customer   49  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0       Eco              160                      5
# 1  Business             2863                      1
# 2       Eco              192                      2
# 3  Business             3377                      0
# 4       Eco             1182                      2
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  1  ...                       4
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 25

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25976 entries, 0 to 25975
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0                         25976 non-null  int64
#  1   id                                 25976 non-null  int64
#  2   Gender                             25976 non-null  object
#  3   Customer Type                      25976 non-null  object
#  4   Age                                25976 non-null  int64
#  5   Type of Travel                     25976 non-null  object
#  6   Class                              25976 non-null  object
#  7   Flight Distance                    25976 non-null  int64
#  8   Inflight wifi service              25976 non-null  int64
#  9   Departure/Arrival time convenient  25976 non-null  int64
#  10  Ease of Online booking             25976 non-null  int64
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0             id           Age  Flight Distance  \
# count  25976.000000   25976.000000  25976.000000     25976.000000
# mean   12987.500000   65005.657992     39.620958      1193.788459
# std     7498.769632   37611.526647     15.135685       998.683999
# min        0.000000      17.000000      7.000000        31.000000
# 25%     6493.750000   32170.500000     27.000000       414.000000
# 50%    12987.500000   65319.500000     40.000000       849.000000
# 75%    19481.250000   97584.250000     51.000000      1744.000000
# max    25975.000000  129877.000000     85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count           25976.000000                       25976.000000
# mean                2.724746                           3.046812
# std                 1.335384                           1.533371
# min                 0.000000                           0.000000
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                            0
# id                                    0
# Gender                                0
# Customer Type                         0
# Age                                   0
# Type of Travel                        0
# Class                                 0
# Flight Distance                       0
# Inflight wifi service                 0
# Departure/Arrival time convenient     0
# Ease of Online booking                0
# Gate location                         0
# Food and drink                        0
# Online boarding                       0
# Seat comfort                          0
# Inflight entertainment                0
# On-board service                      0
# Leg room service                      0
# Baggage handling                      0
# Checkin service                       0
# Inflight service                      0
# Cleanliness                           0
# Departure Delay in Minutes            0
# ...

# %%
from statistics import mean as mean
meanval=mean(df["Arrival Delay in Minutes"])

# %%
for i in df["Arrival Delay in Minutes"]:
  if(i==None):
    i=meanval

# %%
df["Arrival Delay in Minutes"]
# Out:
# 0        44.0
# 1         0.0
# 2         0.0
# 3         6.0
# 4        20.0
#          ...
# 25971     0.0
# 25972     0.0
# 25973     0.0
# 25974     0.0
# 25975     0.0
# Name: Arrival Delay in Minutes, Length: 25976, dtype: float64

# %%
df["Arrival Delay in Minutes"]=df["Arrival Delay in Minutes"].fillna(meanval)

# %%
df["Type of Travel"].unique()
df["Class"].unique()
# Out:
# array(['Eco', 'Business', 'Eco Plus'], dtype=object)

# %%
from sklearn import preprocessing
encoder=preprocessing.LabelEncoder()

# %%
df["Class"]=encoder.fit_transform(df["Class"])
df["Type of Travel"]=encoder.fit_transform(df["Type of Travel"])

df.head()
# Out:
#    Unnamed: 0     id  Gender      Customer Type  Age  Type of Travel  Class  \
# 0           0  19556  Female     Loyal Customer   52               0      1
# 1           1  90035  Female     Loyal Customer   36               0      0
# 2           2  12360    Male  disloyal Customer   20               0      1
# 3           3  77959    Male     Loyal Customer   44               0      0
# 4           4  36875  Female     Loyal Customer   49               0      1
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              160                      5                                  4
# 1             2863                      1                                  1
# 2              192                      2                                  0
# 3             3377                      0                                  0
# 4             1182                      2                                  3
#
# ...

# %%
df['Class'].value_counts()
# Out:
# 0    12495
# 1    11564
# 2     1917
# Name: Class, dtype: int64

# %%
df.columns = [c.replace(' ', '_') for c in df.columns]

# %%
df
# Out:
#        Unnamed:_0     id  Gender      Customer_Type  Age  Type_of_Travel  \
# 0               0  19556  Female     Loyal Customer   52               0
# 1               1  90035  Female     Loyal Customer   36               0
# 2               2  12360    Male  disloyal Customer   20               0
# 3               3  77959    Male     Loyal Customer   44               0
# 4               4  36875  Female     Loyal Customer   49               0
# ...           ...    ...     ...                ...  ...             ...
# 25971       25971  78463    Male  disloyal Customer   34               0
# 25972       25972  71167    Male     Loyal Customer   23               0
# 25973       25973  37675  Female     Loyal Customer   17               1
# 25974       25974  90086    Male     Loyal Customer   14               0
# 25975       25975  34799  Female     Loyal Customer   42               1
#
#        Class  Flight_Distance  Inflight_wifi_service  \
# ...

# %%
df["satisfaction"]=encoder.fit_transform(df["satisfaction"])
df["Customer_Type"]=encoder.fit_transform(df["Customer_Type"])
df["Gender"]=encoder.fit_transform(df["Gender"])


df
# Out:
#        Unnamed:_0     id  Gender  Customer_Type  Age  Type_of_Travel  Class  \
# 0               0  19556       0              0   52               0      1
# 1               1  90035       0              0   36               0      0
# 2               2  12360       1              1   20               0      1
# 3               3  77959       1              0   44               0      0
# 4               4  36875       0              0   49               0      1
# ...           ...    ...     ...            ...  ...             ...    ...
# 25971       25971  78463       1              1   34               0      0
# 25972       25972  71167       1              0   23               0      0
# 25973       25973  37675       0              0   17               1      1
# 25974       25974  90086       1              0   14               0      0
# 25975       25975  34799       0              0   42               1      1
#
#        Flight_Distance  Inflight_wifi_service  \
# ...

# %%
df=df.drop("Unnamed:_0",axis=1)
df=df.drop("id",axis=1)

# %%
df.corr()
# Out:
#                                      Gender  Customer_Type       Age  \
# Gender                             1.000000      -0.027878  0.009261
# Customer_Type                     -0.027878       1.000000 -0.294210
# Age                                0.009261      -0.294210  1.000000
# Type_of_Travel                     0.019930      -0.307827 -0.029773
# Class                             -0.006411       0.044415 -0.115125
# Flight_Distance                   -0.005222      -0.229306  0.099409
# Inflight_wifi_service             -0.006323       0.001333  0.009242
# Departure/Arrival_time_convenient  0.008417      -0.206864  0.032449
# Ease_of_Online_booking             0.001703      -0.012340  0.013565
# Gate_location                     -0.005628      -0.001940  0.003308
# Food_and_drink                    -0.014422      -0.047269  0.023841
# Online_boarding                   -0.056031      -0.188418  0.202058
# Seat_comfort                      -0.047765      -0.143362  0.154507
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25976 entries, 0 to 25975
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Gender                             25976 non-null  int64
#  1   Customer_Type                      25976 non-null  int64
#  2   Age                                25976 non-null  int64
#  3   Type_of_Travel                     25976 non-null  int64
#  4   Class                              25976 non-null  int64
#  5   Flight_Distance                    25976 non-null  int64
#  6   Inflight_wifi_service              25976 non-null  int64
#  7   Departure/Arrival_time_convenient  25976 non-null  int64
#  8   Ease_of_Online_booking             25976 non-null  int64
#  9   Gate_location                      25976 non-null  int64
#  10  Food_and_drink                     25976 non-null  int64
# ...

# %%
print(df['Arrival_Delay_in_Minutes'].median())
print(max(df['Arrival_Delay_in_Minutes']))
print(min(df['Arrival_Delay_in_Minutes']))
import statistics
print(statistics.mode(df["Arrival_Delay_in_Minutes"]))
df['Arrival_Delay_in_Minutes'].value_counts()
# Out:
# 0.0
# 1115.0
# 0.0
# 0.0
# 0.0      14594
# 1.0        536
# 2.0        523
# 3.0        490
# 4.0        466
#          ...
# 307.0        1
# 285.0        1
# 347.0        1
# 795.0        1
# 288.0        1
# Name: Arrival_Delay_in_Minutes, Length: 320, dtype: int64

# %% [markdown]
# **Filling levels based on Arrival_Delay_in_Minutes**

# %%
for i in df["Arrival_Delay_in_Minutes"]:
  if(i<=360):
    df["Delay Status"]="Short Delay"
  elif(i>360 and i<=720):
   df["Delay Status"]="Medium Delay"
  else:
   df["Delay Status"]="Long Delay"

# %%
df
# Out:
#        Gender  Customer_Type  Age  Type_of_Travel  Class  Flight_Distance  \
# 0           0              0   52               0      1              160
# 1           0              0   36               0      0             2863
# 2           1              1   20               0      1              192
# 3           1              0   44               0      0             3377
# 4           0              0   49               0      1             1182
# ...       ...            ...  ...             ...    ...              ...
# 25971       1              1   34               0      0              526
# 25972       1              0   23               0      0              646
# 25973       0              0   17               1      1              828
# 25974       1              0   14               0      0             1127
# 25975       0              0   42               1      1              264
#
#        Inflight_wifi_service  Departure/Arrival_time_convenient  \
# ...

# %%
plt.hist(df['Arrival_Delay_in_Minutes'])
# Out:
# (array([2.5231e+04, 5.3000e+02, 9.4000e+01, 2.4000e+01, 5.0000e+00,
#         4.0000e+00, 1.0000e+00, 2.0000e+00, 1.0000e+00, 1.0000e+00]),
#  array([   0. ,  111.5,  223. ,  334.5,  446. ,  557.5,  669. ,  780.5,
#          892. , 1003.5, 1115. ]),
#  <a list of 10 Patch objects>)

# %%
df['Gender'].value_counts()
# Out:
# 0    13172
# 1    12804
# Name: Gender, dtype: int64

# %%
print(df.groupby("Class")["Age"].agg(lambda x:x.value_counts().index[0]))
print("0:Business Class, 1:Economic Class , 2:First Class")
# Out:
# Class
# 0    39
# 1    22
# 2    25
# Name: Age, dtype: int64
# 0:Business Class, 1:Economic Class , 2:First Class

# %% [markdown]
# **Exploratory Data Analysis**

# %%
with sns.axes_style(style='ticks'):
    g = sns.catplot("satisfaction", col="Gender", col_wrap=2, data=df, kind="count", height=2.5, aspect=1.0)  
    g = sns.catplot("satisfaction", col="Customer_Type", col_wrap=2, data=df, kind="count", height=2.5, aspect=1.0)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
with sns.axes_style('white'):
    g = sns.catplot("Age", data=df, aspect=3.0, kind='count', hue='satisfaction', order=range(5, 80))
    g.set_ylabels('Age vs Passenger Satisfaction')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
with sns.axes_style('white'):
    g = sns.catplot(x="Departure/Arrival_time_convenient", y="Online_boarding", hue="satisfaction", col="Class", data=df, kind="bar", height=4.5, aspect=.8)

# %%
with sns.axes_style('white'):
    g = sns.catplot(x="Class", y="Departure_Delay_in_Minutes", hue="satisfaction", col="Type_of_Travel", data=df, kind="bar", height=4.5, aspect=.8)
    g = sns.catplot(x="Class", y="Arrival_Delay_in_Minutes", hue="satisfaction", col="Type_of_Travel", data=df, kind="bar", height=4.5, aspect=.8)

# %%
with sns.axes_style('white'):
    g = sns.catplot(x="Gate_location", y="Baggage_handling", hue="satisfaction", col="Class", data=df, kind="box", height=4.5, aspect=.8)

# %%
with sns.axes_style('white'):
    g = sns.catplot(x="Inflight_wifi_service", y="Inflight_entertainment", hue="satisfaction", col="Class", data=df, kind="box", height=4.5, aspect=.8)

# %%
with sns.axes_style(style='ticks'):
    g = sns.catplot("satisfaction", col="Ease_of_Online_booking", col_wrap=6, data=df, kind="count", height=2.5, aspect=.9)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
with sns.axes_style(style='ticks'):
    g = sns.catplot("satisfaction", col="Seat_comfort", col_wrap=6, data=df, kind="count", height=2.5, aspect=.8)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
with sns.axes_style(style='ticks'):
    g = sns.catplot("satisfaction", col="Cleanliness", col_wrap=6, data=df, kind="count", height=2.5, aspect=.8)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
with sns.axes_style(style='ticks'):
    g = sns.catplot("satisfaction", col="Food_and_drink", col_wrap=6, data=df, kind="count", height=2.5, aspect=.8)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
import matplotlib.pyplot as plt 
fig, axarr = plt.subplots(2, 2, figsize=(12, 8))

table1 = pd.crosstab(df['satisfaction'],df['Checkin_service'])
sns.heatmap(table1, cmap='Oranges', ax = axarr[0][0])
table2 = pd.crosstab(df['satisfaction'], df['Inflight_service'])
sns.heatmap(table2, cmap='Blues', ax = axarr[0][1])
table3 = pd.crosstab(df['satisfaction'], df['On-board_service'])
sns.heatmap(table3, cmap='pink', ax = axarr[1][0])
table4 = pd.crosstab(df['satisfaction'], df['Leg_room_service'])
sns.heatmap(table4, cmap='bone', ax = axarr[1][1])

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Gender                                  1.0
# Customer_Type                           0.0
# Age                                    24.0
# Type_of_Travel                          1.0
# Class                                   1.0
# Flight_Distance                      1330.0
# Inflight_wifi_service                   2.0
# Departure/Arrival_time_convenient       2.0
# Ease_of_Online_booking                  2.0
# Gate_location                           2.0
# Food_and_drink                          2.0
# Online_boarding                         2.0
# Seat_comfort                            3.0
# Inflight_entertainment                  2.0
# On-board_service                        2.0
# Leg_room_service                        2.0
# Baggage_handling                        2.0
# Checkin_service                         1.0
# Inflight_service                        2.0
# Cleanliness                             2.0
# Departure_Delay_in_Minutes             12.0
# ...

# %%
df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
df.shape
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   """Entry point for launching an IPython kernel.
# (15234, 24)

# %%
corr = df.corr()
mask = np.triu(np.ones_like(corr, dtype=np.bool))
f, ax = plt.subplots(figsize=(22, 22))
cmap = sns.diverging_palette(150, 1, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=None, center=0,square=True, annot=True, linewidths=.5, cbar_kws={"shrink": .9})
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
df["Delay Status"]=encoder.fit_transform(df["Delay Status"])
df["Delay Status"]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 1        0
# 3        0
# 4        0
# 8        0
# 9        0
#         ..
# 25968    0
# 25969    0
# 25972    0
# 25973    0
# 25974    0
# Name: Delay Status, Length: 15234, dtype: int64

# %%
from sklearn import preprocessing
r_scaler = preprocessing.MinMaxScaler()
df=r_scaler.fit_transform(df)
df=pd.DataFrame(df,columns=[["Gender"	,"Customer_Type"	,"Age"	,"Type_of_Travel",	"Class",	"Flight_Distance"	,"Inflight_wifi_service",	"Departure/Arrival_time_convenient"	,"Ease_of_Online_booking"	,"Gate_location","Food_and_drink" , "Online_boarding", "Seat_comfort", "Inflight_entertainment","On-board_service"	,"Leg_room_service"	,"Baggage_handling"	,"Checkin_service"	,"Inflight_service",	"Cleanliness"	,"Departure_Delay_in_Minutes"	,"Arrival_Delay_in_Minutes",	"satisfaction",	"Delay Status"]])
df
# Out:
#       Gender Customer_Type       Age Type_of_Travel Class Flight_Distance  \
# 0        0.0           0.0  0.371795            0.0   0.0        0.763754
# 1        1.0           0.0  0.474359            0.0   0.0        0.902373
# 2        0.0           0.0  0.538462            0.0   0.5        0.310410
# 3        1.0           0.0  0.512821            0.0   0.5        0.141586
# 4        0.0           0.0  0.500000            0.0   0.0        0.461974
# ...      ...           ...       ...            ...   ...             ...
# 15229    1.0           0.0  0.435897            0.0   0.5        0.178263
# 15230    1.0           0.0  0.576923            0.0   0.0        0.067152
# 15231    1.0           0.0  0.205128            0.0   0.0        0.165858
# 15232    0.0           0.0  0.128205            1.0   0.5        0.214941
# 15233    1.0           0.0  0.089744            0.0   0.0        0.295577
#
#       Inflight_wifi_service Departure/Arrival_time_convenient  \
# ...

# %%
df.isnull().sum()
# Out:
# Gender                                0
# Customer_Type                         0
# Age                                   0
# Type_of_Travel                        0
# Class                                 0
# Flight_Distance                       0
# Inflight_wifi_service                 0
# Departure/Arrival_time_convenient     0
# Ease_of_Online_booking                0
# Gate_location                         0
# Food_and_drink                        0
# Online_boarding                       0
# Seat_comfort                          0
# Inflight_entertainment                0
# On-board_service                      0
# Leg_room_service                      0
# Baggage_handling                      0
# Checkin_service                       0
# Inflight_service                      0
# Cleanliness                           0
# Departure_Delay_in_Minutes            0
# Arrival_Delay_in_Minutes             33
# satisfaction                          0
# ...

# %%
df['Arrival_Delay_in_Minutes'] = df['Arrival_Delay_in_Minutes'].fillna(df['Arrival_Delay_in_Minutes'].mean())

# %%
df.isnull().sum()
# Out:
# Gender                               0
# Customer_Type                        0
# Age                                  0
# Type_of_Travel                       0
# Class                                0
# Flight_Distance                      0
# Inflight_wifi_service                0
# Departure/Arrival_time_convenient    0
# Ease_of_Online_booking               0
# Gate_location                        0
# Food_and_drink                       0
# Online_boarding                      0
# Seat_comfort                         0
# Inflight_entertainment               0
# On-board_service                     0
# Leg_room_service                     0
# Baggage_handling                     0
# Checkin_service                      0
# Inflight_service                     0
# Cleanliness                          0
# Departure_Delay_in_Minutes           0
# Arrival_Delay_in_Minutes             0
# satisfaction                         0
# Delay Status                         0
# dtype: int64

# %%
from sklearn.feature_selection import SelectKBest, chi2
X = df.loc[:,df.columns!='satisfaction']
y = df['satisfaction']
selector = SelectKBest(chi2, k=10)
selector.fit(X, y)
X_new = selector.transform(X)
print(X.columns[selector.get_support(indices=True)])
# Out:
# MultiIndex([(        'Type_of_Travel',),
#             (                 'Class',),
#             (       'Flight_Distance',),
#             (       'Online_boarding',),
#             (          'Seat_comfort',),
#             ('Inflight_entertainment',),
#             (      'On-board_service',),
#             (      'Leg_room_service',),
#             (           'Cleanliness',),
#             (          'satisfaction',)],
#            )
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   FutureWarning,

# %%
df
# Out:
#       Gender Customer_Type       Age Type_of_Travel Class Flight_Distance  \
# 0        0.0           0.0  0.371795            0.0   0.0        0.763754
# 1        1.0           0.0  0.474359            0.0   0.0        0.902373
# 2        0.0           0.0  0.538462            0.0   0.5        0.310410
# 3        1.0           0.0  0.512821            0.0   0.5        0.141586
# 4        0.0           0.0  0.500000            0.0   0.0        0.461974
# ...      ...           ...       ...            ...   ...             ...
# 15229    1.0           0.0  0.435897            0.0   0.5        0.178263
# 15230    1.0           0.0  0.576923            0.0   0.0        0.067152
# 15231    1.0           0.0  0.205128            0.0   0.0        0.165858
# 15232    0.0           0.0  0.128205            1.0   0.5        0.214941
# 15233    1.0           0.0  0.089744            0.0   0.0        0.295577
#
#       Inflight_wifi_service Departure/Arrival_time_convenient  \
# ...

# %%
X=df[[ 'Type_of_Travel',
                            'Class',
                  'Flight_Distance',
                   'Online_boarding',
                      'Seat_comfort',
            'Inflight_entertainment',
                  'On-board_service',
                  'Leg_room_service',
                       'Cleanliness']]

# %%
y=df['satisfaction']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
import graphviz
from sklearn.tree import DecisionTreeClassifier, export_graphviz

# %%
names=['Type_of_Travel',
                            'Class',
                  'Flight_Distance',
                   'Online_boarding',
                      'Seat_comfort',
            'Inflight_entertainment',
                  'On-board_service',
                  'Leg_room_service',
                       'Cleanliness']

# %%
data = export_graphviz(DecisionTreeClassifier(max_depth=3).fit(X_train, y_train), out_file=None, 
                       feature_names =  names,
                       class_names = ['Dissatisfied (0)', 'Satisfied (1)'], 
                       filled = True, rounded = True, special_characters = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   FutureWarning,

# %%
graph = graphviz.Source(data)
graph

# %%
model=DecisionTreeClassifier(max_depth=3).fit(X_train, y_train)
y_pred=model.predict(X_test)
y_pred
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   FutureWarning,
# array([1., 0., 0., ..., 1., 0., 0.])

# %%
from sklearn.metrics import mean_squared_error
error=mean_squared_error(y_test, y_pred)
print(error)
# Out:
# 0.11224154906465376

# %%
score = model.score(X_test,y_test)
print("R-squared:", score)
# Out:
# R-squared: 0.8877584509353462
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   FutureWarning,

# %%
from sklearn.linear_model import LogisticRegression
model2 = LogisticRegression(multi_class='multinomial', solver='lbfgs')
model2.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(multi_class='multinomial')

# %%
y_pred=model2.predict(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   FutureWarning,

# %%
from sklearn.metrics import confusion_matrix
cf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(cf_matrix, annot=True)

# %%
from sklearn.metrics import mean_squared_error
error=mean_squared_error(y_test, y_pred)
print(error)
# Out:
# 0.11814899901542501

# %%
score = model2.score(X_test,y_test)
print("R-squared:", score)
# Out:
# R-squared: 0.881851000984575
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   FutureWarning,
